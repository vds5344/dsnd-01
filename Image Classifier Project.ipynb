# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.
#
# Please make sure if you are running this notebook in the workspace that you have chosen GPU rather than CPU mode.

# %%
# Imports here
import matplotlib.pyplot as plt

import torch
import numpy as np
from torch import nn
from torch import optim
import torch.nn.functional as F
from torchvision import datasets, transforms, models

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomRotation(30),
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
     ]),
    'valid': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
     ]),
    'test': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
     ])
}

# TODO: Load the datasets with ImageFolder
image_datasets = {
    'train_data': datasets.ImageFolder(data_dir + '/train', transform=data_transforms['train']),
    'valid_data': datasets.ImageFolder(data_dir + '/valid', transform=data_transforms['valid']),
    'test_data': datasets.ImageFolder(data_dir + '/test', transform=data_transforms['test'])
}

# TODO: Using the image datasets and the trainforms, define the dataloaders
dataloaders = {
    'trainloader': torch.utils.data.DataLoader(image_datasets['train_data'], batch_size=64, shuffle=True),
    'validloader': torch.utils.data.DataLoader(image_datasets['valid_data'], batch_size=32),
    'testloader': torch.utils.data.DataLoader(image_datasets['test_data'], batch_size=20)
}

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.

# %%
# TODO: Build and train your network
import torchvision.models as models
#resnet18 = models.resnet18(pretrained=True)
#alexnet = models.alexnet(pretrained=True)
#squeezenet = models.squeezenet1_0(pretrained=True)
vgg16 = models.vgg16(pretrained=True)
vgg16
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.torch/models/vgg16-397923af.pth
# 100%|██████████| 553433881/553433881 [00:04<00:00, 120583252.78it/s]
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace)
#     (2): Dropout(p=0.5)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace)
#     (5): Dropout(p=0.5)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
for param in vgg16.parameters():
    param.requires_grad = False

from collections import OrderedDict
classifier = nn.Sequential(OrderedDict([
    ('dropout',nn.Dropout(0.5)),
    ('inputs', nn.Linear(25088, 256)),
    ('relu1', nn.ReLU()),
    ('hidden_layer1', nn.Linear(256, 128)),
    ('relu2',nn.ReLU()),
    ('hidden_layer2',nn.Linear(128,64)),
    ('relu3',nn.ReLU()),
    ('hidden_layer3',nn.Linear(64,102)),
    ('output', nn.LogSoftmax(dim=1))
        ]))
    
vgg16.classifier = classifier

# %%
import time
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
criterion = nn.NLLLoss()
# Only train the classifier parameters, feature parameters are frozen
optimizer = optim.Adam(vgg16.classifier.parameters(), lr=0.001)

vgg16.to(device)

for ii, (inputs, labels) in enumerate(dataloaders['trainloader']):

# Move input and label tensors to the GPU
    inputs, labels = inputs.to(device), labels.to(device)

    start = time.time()

    outputs = vgg16.forward(inputs)
    loss = criterion(outputs, labels)
    loss.backward()
    optimizer.step()

    #if ii==3:
     #   break
        
#print(f"DEVICE = {device}; Time per batch: {(time.time() - start)/3:.3f} seconds")

# %%
# TODO: Train a model with a pre-trained network

criterion = nn.NLLLoss()
optimizer = optim.Adam(vgg16.classifier.parameters(), lr=0.001)

# %%
epochs = 20
print_every = 10
steps = 0

# change to cuda
vgg16.to('cuda')

for e in range(epochs):
    running_loss = 0
    for ii, (inputs, labels) in enumerate(dataloaders['trainloader']):
        steps += 1
        
        inputs, labels = inputs.to('cuda'), labels.to('cuda')
        
        optimizer.zero_grad()
        
        # Forward and backward passes
        outputs = vgg16.forward(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        
        if steps % print_every == 0:
            vgg16.eval()

            vlost = 0
            accuracy=0
            
            
            for ii, (inputs2,labels2) in enumerate(dataloaders['validloader']):
                optimizer.zero_grad()
                
                inputs2, labels2 = inputs2.to('cuda:0') , labels2.to('cuda:0')
                vgg16.to('cuda:0')
                with torch.no_grad():    
                    outputs = vgg16.forward(inputs2)
                    vlost = criterion(outputs,labels2)
                    ps = torch.exp(outputs).data
                    equality = (labels2.data == ps.max(1)[1])
                    accuracy += equality.type_as(torch.FloatTensor()).mean()
                    
            vlost = vlost / len(dataloaders['validloader'])
            accuracy = accuracy /len(dataloaders['validloader'])
            
                    
            
            print("Epoch: {}/{} ".format(e+1, epochs),
                  "Loss: {}".format(running_loss/print_every),
                  "Validation Lost {}".format(vlost),
                   "Accuracy: {}".format(accuracy))
            
            vgg16.train()
            running_loss = 0
                # Turn off gradients for validation, will speed up inference
            #with torch.no_grad():
             #   test_loss, accuracy = validation(vgg16, dataloaders['testloader'], criterion)
                
            #print("Epoch: {}/{}.. ".format(e+1, epochs),
             #     "Training Loss: {:.3f}.. ".format(running_loss/print_every),
              #    "Test Loss: {:.3f}.. ".format(test_loss/len(dataloaders['testloader'])),
               #   "Test Accuracy: {:.3f}".format(accuracy/len(dataloaders['testloader'])))
                
            #running_loss = 0
                
                # Make sure dropout and grads are on for training
            #vgg16.train()
            #print("Epoch: {}/{}... ".format(e+1, epochs),
             #     "Loss: {:.4f}".format(running_loss/print_every))
            
            #running_loss = 0
# Out:
# Epoch: 1/20...  Loss: 3.6779 Validation Lost 0.1796 Accuracy: 0.1502
# Epoch: 1/20...  Loss: 3.6629 Validation Lost 0.1823 Accuracy: 0.1767
# Epoch: 1/20...  Loss: 3.6356 Validation Lost 0.1803 Accuracy: 0.1887
# Epoch: 1/20...  Loss: 3.4852 Validation Lost 0.1802 Accuracy: 0.2043
# Epoch: 1/20...  Loss: 3.3968 Validation Lost 0.1804 Accuracy: 0.2139
# Epoch: 1/20...  Loss: 3.3062 Validation Lost 0.1773 Accuracy: 0.2332
# Epoch: 1/20...  Loss: 3.2809 Validation Lost 0.1709 Accuracy: 0.2500
# Epoch: 1/20...  Loss: 3.0840 Validation Lost 0.1656 Accuracy: 0.2500
# Epoch: 1/20...  Loss: 3.0135 Validation Lost 0.1649 Accuracy: 0.2788
# Epoch: 1/20...  Loss: 3.0582 Validation Lost 0.1536 Accuracy: 0.2752
# Epoch: 2/20...  Loss: 2.1317 Validation Lost 0.1464 Accuracy: 0.2933
# Epoch: 2/20...  Loss: 2.8185 Validation Lost 0.1273 Accuracy: 0.3125
# Epoch: 2/20...  Loss: 2.7530 Validation Lost 0.1365 Accuracy: 0.3401
# Epoch: 2/20...  Loss: 2.5903 Validation Lost 0.1392 Accuracy: 0.3450
# Epoch: 2/20...  Loss: 2.6854 Validation Lost 0.1389 Accuracy: 0.3774
# Epoch: 2/20...  Loss: 2.5984 Validation Lost 0.1214 Accuracy: 0.4054
# Epoch: 2/20...  Loss: 2.3914 Validation Lost 0.1129 Accuracy: 0.4100
# Epoch: 2/20...  Loss: 2.4822 Validation Lost 0.0918 Accuracy: 0.4200
# Epoch: 2/20...  Loss: 2.4491 Validation Lost 0.0910 Accuracy: 0.4284
# Epoch: 2/20...  Loss: 2.5298 Validation Lost 0.0890 Accuracy: 0.4669
# Epoch: 3/20...  Loss: 0.9217 Validation Lost 0.0930 Accuracy: 0.4491
# Epoch: 3/20...  Loss: 2.2609 Validation Lost 0.0939 Accuracy: 0.4609
# Epoch: 3/20...  Loss: 2.2210 Validation Lost 0.0869 Accuracy: 0.4798
# Epoch: 3/20...  Loss: 2.2040 Validation Lost 0.0966 Accuracy: 0.4538
# Epoch: 3/20...  Loss: 2.0364 Validation Lost 0.1000 Accuracy: 0.4692
# Epoch: 3/20...  Loss: 2.2052 Validation Lost 0.0797 Accuracy: 0.4955
# Epoch: 3/20...  Loss: 2.3168 Validation Lost 0.0864 Accuracy: 0.4915
# Epoch: 3/20...  Loss: 2.1313 Validation Lost 0.0701 Accuracy: 0.5027
# Epoch: 3/20...  Loss: 2.0674 Validation Lost 0.0791 Accuracy: 0.5060
# Epoch: 3/20...  Loss: 2.0604 Validation Lost 0.0650 Accuracy: 0.5355
# Epoch: 4/20...  Loss: 0.2060 Validation Lost 0.0793 Accuracy: 0.5325
# Epoch: 4/20...  Loss: 2.0484 Validation Lost 0.0766 Accuracy: 0.5174
# Epoch: 4/20...  Loss: 2.0363 Validation Lost 0.0602 Accuracy: 0.5418
# Epoch: 4/20...  Loss: 2.0204 Validation Lost 0.0687 Accuracy: 0.5529
# Epoch: 4/20...  Loss: 1.9939 Validation Lost 0.0595 Accuracy: 0.5584
# Epoch: 4/20...  Loss: 1.9035 Validation Lost 0.0588 Accuracy: 0.5538
# Epoch: 4/20...  Loss: 2.0074 Validation Lost 0.0636 Accuracy: 0.5613
# Epoch: 4/20...  Loss: 2.0130 Validation Lost 0.0638 Accuracy: 0.5637
# Epoch: 4/20...  Loss: 1.9203 Validation Lost 0.0671 Accuracy: 0.5745
# Epoch: 4/20...  Loss: 1.9002 Validation Lost 0.0497 Accuracy: 0.5788
# Epoch: 4/20...  Loss: 1.9629 Validation Lost 0.0594 Accuracy: 0.5514
# Epoch: 5/20...  Loss: 1.4729 Validation Lost 0.0631 Accuracy: 0.5658
# Epoch: 5/20...  Loss: 1.7622 Validation Lost 0.0697 Accuracy: 0.5724
# Epoch: 5/20...  Loss: 1.9038 Validation Lost 0.0507 Accuracy: 0.6173
# Epoch: 5/20...  Loss: 1.8258 Validation Lost 0.0518 Accuracy: 0.6022
# Epoch: 5/20...  Loss: 1.7838 Validation Lost 0.0534 Accuracy: 0.6098
# Epoch: 5/20...  Loss: 1.8443 Validation Lost 0.0474 Accuracy: 0.6155
# Epoch: 5/20...  Loss: 1.8136 Validation Lost 0.0457 Accuracy: 0.6122
# Epoch: 5/20...  Loss: 1.7191 Validation Lost 0.0515 Accuracy: 0.6173
# Epoch: 5/20...  Loss: 1.8237 Validation Lost 0.0563 Accuracy: 0.6052
# Epoch: 5/20...  Loss: 1.7031 Validation Lost 0.0390 Accuracy: 0.6450
# Epoch: 6/20...  Loss: 0.8037 Validation Lost 0.0418 Accuracy: 0.6215
# Epoch: 6/20...  Loss: 1.7073 Validation Lost 0.0412 Accuracy: 0.6194
# Epoch: 6/20...  Loss: 1.6299 Validation Lost 0.0374 Accuracy: 0.6429
# Epoch: 6/20...  Loss: 1.6665 Validation Lost 0.0448 Accuracy: 0.6098
# Epoch: 6/20...  Loss: 1.6785 Validation Lost 0.0529 Accuracy: 0.6221
# Epoch: 6/20...  Loss: 1.6271 Validation Lost 0.0426 Accuracy: 0.6317
# Epoch: 6/20...  Loss: 1.6988 Validation Lost 0.0362 Accuracy: 0.6528
# Epoch: 6/20...  Loss: 1.7382 Validation Lost 0.0432 Accuracy: 0.6405
# Epoch: 6/20...  Loss: 1.6875 Validation Lost 0.0456 Accuracy: 0.6470
# Epoch: 6/20...  Loss: 1.6495 Validation Lost 0.0503 Accuracy: 0.6305
# Epoch: 7/20...  Loss: 0.3373 Validation Lost 0.0389 Accuracy: 0.6384
# Epoch: 7/20...  Loss: 1.5526 Validation Lost 0.0463 Accuracy: 0.6579
# Epoch: 7/20...  Loss: 1.6745 Validation Lost 0.0510 Accuracy: 0.6398
# Epoch: 7/20...  Loss: 1.6110 Validation Lost 0.0420 Accuracy: 0.6663
# Epoch: 7/20...  Loss: 1.5082 Validation Lost 0.0371 Accuracy: 0.6720
# Epoch: 7/20...  Loss: 1.3926 Validation Lost 0.0375 Accuracy: 0.6636
# Epoch: 7/20...  Loss: 1.5597 Validation Lost 0.0352 Accuracy: 0.6573
# Epoch: 7/20...  Loss: 1.5902 Validation Lost 0.0356 Accuracy: 0.6874
# Epoch: 7/20...  Loss: 1.5230 Validation Lost 0.0478 Accuracy: 0.6888
# Epoch: 7/20...  Loss: 1.6053 Validation Lost 0.0508 Accuracy: 0.6699
# Epoch: 7/20...  Loss: 1.5081 Validation Lost 0.0421 Accuracy: 0.6792
# Epoch: 8/20...  Loss: 1.3543 Validation Lost 0.0426 Accuracy: 0.6843
# Epoch: 8/20...  Loss: 1.4938 Validation Lost 0.0367 Accuracy: 0.6946
# Epoch: 8/20...  Loss: 1.4991 Validation Lost 0.0451 Accuracy: 0.6810
# Epoch: 8/20...  Loss: 1.5544 Validation Lost 0.0327 Accuracy: 0.6960
# Epoch: 8/20...  Loss: 1.4466 Validation Lost 0.0290 Accuracy: 0.6946
# Epoch: 8/20...  Loss: 1.4926 Validation Lost 0.0301 Accuracy: 0.6886
# Epoch: 8/20...  Loss: 1.3271 Validation Lost 0.0393 Accuracy: 0.6951
# Epoch: 8/20...  Loss: 1.5200 Validation Lost 0.0362 Accuracy: 0.6987
# Epoch: 8/20...  Loss: 1.4668 Validation Lost 0.0368 Accuracy: 0.6939
# Epoch: 8/20...  Loss: 1.6069 Validation Lost 0.0343 Accuracy: 0.6958
# Epoch: 9/20...  Loss: 0.8511 Validation Lost 0.0296 Accuracy: 0.6946
# Epoch: 9/20...  Loss: 1.3759 Validation Lost 0.0315 Accuracy: 0.6874
# Epoch: 9/20...  Loss: 1.5121 Validation Lost 0.0325 Accuracy: 0.7066
# Epoch: 9/20...  Loss: 1.5372 Validation Lost 0.0376 Accuracy: 0.7066
# Epoch: 9/20...  Loss: 1.3089 Validation Lost 0.0393 Accuracy: 0.7141
# Epoch: 9/20...  Loss: 1.3833 Validation Lost 0.0372 Accuracy: 0.7294
# Epoch: 9/20...  Loss: 1.3125 Validation Lost 0.0402 Accuracy: 0.7018
# Epoch: 9/20...  Loss: 1.4578 Validation Lost 0.0407 Accuracy: 0.7009
# Epoch: 9/20...  Loss: 1.4083 Validation Lost 0.0325 Accuracy: 0.7018
# Epoch: 9/20...  Loss: 1.4070 Validation Lost 0.0314 Accuracy: 0.7138
# Epoch: 10/20...  Loss: 0.3664 Validation Lost 0.0387 Accuracy: 0.7102
# Epoch: 10/20...  Loss: 1.2797 Validation Lost 0.0335 Accuracy: 0.7177
# Epoch: 10/20...  Loss: 1.3281 Validation Lost 0.0453 Accuracy: 0.7047
# Epoch: 10/20...  Loss: 1.4272 Validation Lost 0.0332 Accuracy: 0.7078
# Epoch: 10/20...  Loss: 1.3901 Validation Lost 0.0371 Accuracy: 0.7126
# Epoch: 10/20...  Loss: 1.3403 Validation Lost 0.0324 Accuracy: 0.7174
# Epoch: 10/20...  Loss: 1.3249 Validation Lost 0.0327 Accuracy: 0.7162
# Epoch: 10/20...  Loss: 1.2973 Validation Lost 0.0452 Accuracy: 0.7078
# Epoch: 10/20...  Loss: 1.2971 Validation Lost 0.0359 Accuracy: 0.7138
# Epoch: 10/20...  Loss: 1.3150 Validation Lost 0.0408 Accuracy: 0.7138
# Epoch: 10/20...  Loss: 1.4508 Validation Lost 0.0343 Accuracy: 0.7294
# Epoch: 11/20...  Loss: 1.3118 Validation Lost 0.0209 Accuracy: 0.7244
# Epoch: 11/20...  Loss: 1.2393 Validation Lost 0.0354 Accuracy: 0.7177
# Epoch: 11/20...  Loss: 1.2843 Validation Lost 0.0335 Accuracy: 0.7222
# Epoch: 11/20...  Loss: 1.1311 Validation Lost 0.0388 Accuracy: 0.7294
# Epoch: 11/20...  Loss: 1.3200 Validation Lost 0.0338 Accuracy: 0.7439
# Epoch: 11/20...  Loss: 1.3423 Validation Lost 0.0340 Accuracy: 0.7306
# Epoch: 11/20...  Loss: 1.2775 Validation Lost 0.0352 Accuracy: 0.7306
# Epoch: 11/20...  Loss: 1.4116 Validation Lost 0.0298 Accuracy: 0.7342
# Epoch: 11/20...  Loss: 1.2026 Validation Lost 0.0329 Accuracy: 0.7523
# Epoch: 11/20...  Loss: 1.2400 Validation Lost 0.0359 Accuracy: 0.7535
# Epoch: 12/20...  Loss: 0.8381 Validation Lost 0.0350 Accuracy: 0.7499
# Epoch: 12/20...  Loss: 1.2387 Validation Lost 0.0300 Accuracy: 0.7559
# Epoch: 12/20...  Loss: 1.2204 Validation Lost 0.0330 Accuracy: 0.7270
# Epoch: 12/20...  Loss: 1.2545 Validation Lost 0.0363 Accuracy: 0.7318
# Epoch: 12/20...  Loss: 1.1633 Validation Lost 0.0286 Accuracy: 0.7511
# Epoch: 12/20...  Loss: 1.2096 Validation Lost 0.0328 Accuracy: 0.7463
# Epoch: 12/20...  Loss: 1.2548 Validation Lost 0.0324 Accuracy: 0.7427
# Epoch: 12/20...  Loss: 1.2642 Validation Lost 0.0290 Accuracy: 0.7463
# Epoch: 12/20...  Loss: 1.2961 Validation Lost 0.0331 Accuracy: 0.7523
# Epoch: 12/20...  Loss: 1.1827 Validation Lost 0.0292 Accuracy: 0.7523
# Epoch: 13/20...  Loss: 0.4381 Validation Lost 0.0357 Accuracy: 0.7571
# Epoch: 13/20...  Loss: 1.1800 Validation Lost 0.0358 Accuracy: 0.7523
# Epoch: 13/20...  Loss: 1.1092 Validation Lost 0.0287 Accuracy: 0.7571
# Epoch: 13/20...  Loss: 1.2159 Validation Lost 0.0290 Accuracy: 0.7403
# Epoch: 13/20...  Loss: 1.1769 Validation Lost 0.0291 Accuracy: 0.7715
# Epoch: 13/20...  Loss: 1.1899 Validation Lost 0.0320 Accuracy: 0.7715
# Epoch: 13/20...  Loss: 1.1859 Validation Lost 0.0382 Accuracy: 0.7634
# Epoch: 13/20...  Loss: 1.1889 Validation Lost 0.0299 Accuracy: 0.7547
# Epoch: 13/20...  Loss: 1.1016 Validation Lost 0.0291 Accuracy: 0.7607
# Epoch: 13/20...  Loss: 1.1726 Validation Lost 0.0324 Accuracy: 0.7583
# Epoch: 14/20...  Loss: 0.1353 Validation Lost 0.0381 Accuracy: 0.7631
# Epoch: 14/20...  Loss: 1.1562 Validation Lost 0.0350 Accuracy: 0.7691
# Epoch: 14/20...  Loss: 1.1411 Validation Lost 0.0375 Accuracy: 0.7489
# Epoch: 14/20...  Loss: 1.2175 Validation Lost 0.0396 Accuracy: 0.7703
# Epoch: 14/20...  Loss: 1.1214 Validation Lost 0.0268 Accuracy: 0.7679
# Epoch: 14/20...  Loss: 1.0462 Validation Lost 0.0438 Accuracy: 0.7576
# Epoch: 14/20...  Loss: 1.1775 Validation Lost 0.0276 Accuracy: 0.7739
# Epoch: 14/20...  Loss: 1.2134 Validation Lost 0.0280 Accuracy: 0.7739
# Epoch: 14/20...  Loss: 1.1254 Validation Lost 0.0291 Accuracy: 0.7607
# Epoch: 14/20...  Loss: 1.1929 Validation Lost 0.0299 Accuracy: 0.7715
# Epoch: 14/20...  Loss: 1.1518 Validation Lost 0.0338 Accuracy: 0.7871
# Epoch: 15/20...  Loss: 0.8792 Validation Lost 0.0315 Accuracy: 0.7655
# Epoch: 15/20...  Loss: 1.0341 Validation Lost 0.0262 Accuracy: 0.7943
# Epoch: 15/20...  Loss: 1.1158 Validation Lost 0.0275 Accuracy: 0.7799
# Epoch: 15/20...  Loss: 1.1340 Validation Lost 0.0294 Accuracy: 0.7799
# Epoch: 15/20...  Loss: 1.2171 Validation Lost 0.0418 Accuracy: 0.7658
# Epoch: 15/20...  Loss: 1.1938 Validation Lost 0.0304 Accuracy: 0.7823
# Epoch: 15/20...  Loss: 1.0731 Validation Lost 0.0413 Accuracy: 0.7646
# Epoch: 15/20...  Loss: 1.0989 Validation Lost 0.0294 Accuracy: 0.7811
# Epoch: 15/20...  Loss: 1.1596 Validation Lost 0.0258 Accuracy: 0.7833
# Epoch: 15/20...  Loss: 0.9677 Validation Lost 0.0244 Accuracy: 0.7895
# Epoch: 16/20...  Loss: 0.5118 Validation Lost 0.0311 Accuracy: 0.7703
# Epoch: 16/20...  Loss: 1.1201 Validation Lost 0.0325 Accuracy: 0.7883
# Epoch: 16/20...  Loss: 1.0608 Validation Lost 0.0335 Accuracy: 0.7655
# Epoch: 16/20...  Loss: 1.0577 Validation Lost 0.0351 Accuracy: 0.7898
# Epoch: 16/20...  Loss: 1.0167 Validation Lost 0.0317 Accuracy: 0.7859
# Epoch: 16/20...  Loss: 1.0243 Validation Lost 0.0354 Accuracy: 0.7907
# Epoch: 16/20...  Loss: 1.0266 Validation Lost 0.0330 Accuracy: 0.7919
# Epoch: 16/20...  Loss: 1.0755 Validation Lost 0.0355 Accuracy: 0.7841
# Epoch: 16/20...  Loss: 1.0395 Validation Lost 0.0283 Accuracy: 0.8100
# Epoch: 16/20...  Loss: 1.1531 Validation Lost 0.0318 Accuracy: 0.7955
# Epoch: 17/20...  Loss: 0.2185 Validation Lost 0.0335 Accuracy: 0.7883
# Epoch: 17/20...  Loss: 1.0540 Validation Lost 0.0247 Accuracy: 0.8001
# Epoch: 17/20...  Loss: 0.9903 Validation Lost 0.0283 Accuracy: 0.7727
# Epoch: 17/20...  Loss: 1.0660 Validation Lost 0.0301 Accuracy: 0.7727
# Epoch: 17/20...  Loss: 1.0862 Validation Lost 0.0233 Accuracy: 0.7847
# Epoch: 17/20...  Loss: 1.0411 Validation Lost 0.0343 Accuracy: 0.7874
# Epoch: 17/20...  Loss: 1.1726 Validation Lost 0.0330 Accuracy: 0.7958
# Epoch: 17/20...  Loss: 1.0074 Validation Lost 0.0302 Accuracy: 0.7850
# Epoch: 17/20...  Loss: 1.0593 Validation Lost 0.0258 Accuracy: 0.7931
# Epoch: 17/20...  Loss: 0.9980 Validation Lost 0.0320 Accuracy: 0.7847
# Epoch: 17/20...  Loss: 1.0044 Validation Lost 0.0291 Accuracy: 0.8076
# Epoch: 18/20...  Loss: 0.8392 Validation Lost 0.0316 Accuracy: 0.8136
# Epoch: 18/20...  Loss: 1.0568 Validation Lost 0.0284 Accuracy: 0.8064
# Epoch: 18/20...  Loss: 0.9854 Validation Lost 0.0284 Accuracy: 0.7967
# Epoch: 18/20...  Loss: 1.0866 Validation Lost 0.0297 Accuracy: 0.7955
# Epoch: 18/20...  Loss: 1.0600 Validation Lost 0.0284 Accuracy: 0.7955
# Epoch: 18/20...  Loss: 1.0104 Validation Lost 0.0250 Accuracy: 0.8010
# Epoch: 18/20...  Loss: 1.1597 Validation Lost 0.0272 Accuracy: 0.8052
# Epoch: 18/20...  Loss: 0.9951 Validation Lost 0.0350 Accuracy: 0.8112
# Epoch: 18/20...  Loss: 0.9808 Validation Lost 0.0345 Accuracy: 0.7931
# Epoch: 18/20...  Loss: 1.0469 Validation Lost 0.0294 Accuracy: 0.8088
# Epoch: 19/20...  Loss: 0.6409 Validation Lost 0.0261 Accuracy: 0.7991
# Epoch: 19/20...  Loss: 0.9595 Validation Lost 0.0228 Accuracy: 0.7991
# Epoch: 19/20...  Loss: 0.9686 Validation Lost 0.0262 Accuracy: 0.7991
# Epoch: 19/20...  Loss: 0.9751 Validation Lost 0.0421 Accuracy: 0.7985
# Epoch: 19/20...  Loss: 0.9702 Validation Lost 0.0402 Accuracy: 0.8052
# Epoch: 19/20...  Loss: 1.0532 Validation Lost 0.0264 Accuracy: 0.8136
# Epoch: 19/20...  Loss: 0.9473 Validation Lost 0.0228 Accuracy: 0.8040
# Epoch: 19/20...  Loss: 1.0450 Validation Lost 0.0238 Accuracy: 0.8133
# Epoch: 19/20...  Loss: 1.0143 Validation Lost 0.0327 Accuracy: 0.8184
# Epoch: 19/20...  Loss: 1.0013 Validation Lost 0.0297 Accuracy: 0.8196
# Epoch: 20/20...  Loss: 0.3140 Validation Lost 0.0289 Accuracy: 0.7907
# Epoch: 20/20...  Loss: 1.0535 Validation Lost 0.0191 Accuracy: 0.8001
# Epoch: 20/20...  Loss: 0.9633 Validation Lost 0.0375 Accuracy: 0.7949
# Epoch: 20/20...  Loss: 0.9707 Validation Lost 0.0383 Accuracy: 0.8100
# Epoch: 20/20...  Loss: 0.9497 Validation Lost 0.0244 Accuracy: 0.8196
# Epoch: 20/20...  Loss: 0.9498 Validation Lost 0.0267 Accuracy: 0.8049
# Epoch: 20/20...  Loss: 1.0018 Validation Lost 0.0259 Accuracy: 0.8097
# Epoch: 20/20...  Loss: 1.0675 Validation Lost 0.0297 Accuracy: 0.8112
# Epoch: 20/20...  Loss: 0.9912 Validation Lost 0.0252 Accuracy: 0.8208
# Epoch: 20/20...  Loss: 0.9393 Validation Lost 0.0295 Accuracy: 0.8088
# Epoch: 20/20...  Loss: 0.9996 Validation Lost 0.0271 Accuracy: 0.8030

# %%
correct = 0
total = 0
with torch.no_grad():
    for data in dataloaders['testloader']:
        images, labels = data
        images, labels = images.to('cuda'), labels.to('cuda')
        outputs = vgg16(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the test images: %d %%' % (100 * correct / total))

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Do validation on the test set
correct = 0
total = 0
with torch.no_grad():
    for data in dataloaders['testloader']:
        images, labels = data
        images, labels = images.to('cuda'), labels.to('cuda')
        outputs = vgg16(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the test images: %d %%' % (100 * correct / total))
# Out:
# Accuracy of the network on the test images: 75 %

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint 
vgg16.class_to_idx = image_datasets['train_data'].class_to_idx
vgg16.cpu
torch.save({'state_dict':vgg16.state_dict(),
            'class_to_idx':vgg16.class_to_idx},
            'checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model
def load():
    checkpoint = torch.load('checkpoint.pth')
    vgg16.class_to_idx = checkpoint['class_to_idx']
    vgg16.load_state_dict(checkpoint['state_dict'])
    
    
load()  
print(vgg16)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (dropout): Dropout(p=0.5)
#     (inputs): Linear(in_features=25088, out_features=120, bias=True)
#     (relu1): ReLU()
#     (hidden_layer1): Linear(in_features=120, out_features=90, bias=True)
#     (relu2): ReLU()
#     (hidden_layer2): Linear(in_features=90, out_features=80, bias=True)
#     (relu3): ReLU()
#     (hidden_layer3): Linear(in_features=80, out_features=102, bias=True)
#     (output): LogSoftmax()
#   )
# )

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
from PIL import Image
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    pil_image = Image.open(image)
    img_transform = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
    
    img = img_transform(pil_image)
    return np.array(img)
    # TODO: Process a PIL image for use in a PyTorch model
img_pr = process_image(test_dir+"/17/image_03872.jpg")

# %%
import os
os.listdir(test_dir+"/1")
# Out:
# ['image_06760.jpg',
#  'image_06754.jpg',
#  'image_06743.jpg',
#  'image_06764.jpg',
#  'image_06752.jpg']

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

imshow(process_image(test_dir+"/17/image_03872.jpg"))

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
from torch.autograd import Variable
vgg16.class_to_idx =image_datasets['train_data'].class_to_idx

ctx = vgg16.class_to_idx

def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    
    # TODO: Implement the code to predict the class from an image file
   
    model.to('cuda:0')
    img_torch = process_image(image_path)
    img_torch = Variable(torch.from_numpy(img_torch))
    img_torch = img_torch.unsqueeze_(0)
    img_torch = img_torch.float()
    
    with torch.no_grad():
        output = model.forward(img_torch.cuda())
        
    probability = F.softmax(output.data,dim=1)
    
    return probability.topk(topk)

imga = (test_dir + '/1/image_06760.jpg')
val1, val2 = predict(imga, vgg16)
print(val1)
print(val2)
# Out:
# tensor([[ 0.2504,  0.2291,  0.1381,  0.1077,  0.0855]], device='cuda:0')
# tensor([[ 50,  61,  85,  53,  78]], device='cuda:0')

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes
def check_sanity():
    #plt.rcParams["figure.figsize"] = (10,5)
    #plt.subplot(211)
    
    index = 1
    path = test_dir+"/1/image_06760.jpg"

    res = predict(path, vgg16)
    image = process_image(path)
    

    axs = imshow(image, ax = plt)
    axs.axis('off')
    axs.title(cat_to_name[str(index)])
    axs.show()
    
    
    a = np.array(res[0][0])
    b = [cat_to_name[str(index + 1)] for index in np.array(res[1][0])]
    
    
    N=float(len(b))
    fig,ax = plt.subplots(figsize=(7,5))
    width = 0.8
    tickLocations = np.arange(N)
    ax.bar(tickLocations, a, width, linewidth=3.0, align = 'center')
    ax.set_xticks(ticks = tickLocations)
    ax.set_xticklabels(b)
    ax.set_xlim(min(tickLocations)-0.6,max(tickLocations)+0.6)
    ax.set_yticks([0.2,0.4,0.6,0.8,1,1.2])
    ax.set_ylim((0,1))
    ax.yaxis.grid(True)

    plt.show()
    
check_sanity()
